# %% [markdown]
# # Grouping and Combining Web of Science and Scopus Files
#
# This notebook focuses on grouping and combining records from Web of Science and Scopus files. The goal is to create a single CSV file that consolidates all records from multiple sources, which will be used for modeling in the next steps.

# %%
# Imports
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import os

# Var list global
key_words = []

# %% [markdown]
# ### Create DataFrame Pandas with articles WOS records

# %%
# Directory containing the .xls files
# directory = 'data/articles/scopus'

# dataframes = []

# # Iterate over all files in the specified folder
# for filename in os.listdir(directory):
#     if filename.endswith('.csv'):
#         file_path = os.path.join(directory, filename)
#         print(filename.split('.')[0])
# Out:
# ai

# %%
# Directory containing the .xls files
directory = 'data/articles/wos'

dataframes = []

# Iterate over all files in the specified folder
for filename in os.listdir(directory):
    if filename.endswith('.xls'):
        file_path = os.path.join(directory, filename)
        df = pd.read_excel(file_path)
        key_words.append(filename.split('.')[0])
        df['Source'] = directory.split('/')[-1]+'-'+filename.split('.')[0]
        dataframes.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# If duplicates based on the "Article Title" field, to remove!
df_wos = combined_df.drop_duplicates(subset=['Article Title'])
df_wos.reset_index(drop=True, inplace=True)

df_wos = df_wos[['Article Title','Authors','Publication Year','DOI','Abstract','Author Keywords','Publisher','Source','Times Cited, All Databases']]
df_wos.columns = ['Title','Authors','Year','DOI','Abstract','Keywords','Publisher','Source','Cited']
df_wos.head()
# Out:
#                                                Title  \
# 0  Big-data AI analytics in value-chain innovatio...
# 1  Anthropomorphism in artificial intelligence: a...
# 2  A Primer on Out-of-the-Box AI Marketing Mix Mo...
# 3  Past, present and future of AI in marketing an...
# 4  Unveiling user responses to AI-powered persona...
#
#                                              Authors  Year  \
# 0  Zong, ZP; Anwar, MA; Khan, S; Asmi, F; Hussain, N  2025
# 1                   Gomes, S; Lopes, JM; Nogueira, E  2025
# 2                Estevez, M; Ballestar, MT; Sainz, J  2025
# 3                    Marvi, R; Foroudi, P; Cuomo, MT  2024
# 4                 Ding, L; Antonucci, G; Venditti, M  2024
#
#                           DOI  \
# 0    10.1108/IMR-02-2024-0049
# 1  10.1186/s43093-025-00423-y
# 2    10.1109/TEM.2024.3519172
# 3    10.1108/JKM-07-2023-0634
# 4    10.1108/QMR-11-2023-0151
#
#                                             Abstract  \
# 0  Purpose Despite great consensus on the positiv...
# 1  The expansion of brands adopting artificial in...
# 2  Marketing mix modeling (MMM) optimizes budget ...
# 3  PurposeThis paper aims to explore the intersec...
# 4  PurposeThis study aims to explore the impact o...
#
#                                             Keywords  \
# 0  Big-data-based AI analytics; Digital affordanc...
# 1  Artificial intelligence; Anthropomorphism; Cha...
# 2  Biological system modeling; Artificial intelli...
# 3  Artificial intelligence; Knowledge management;...
# 4  TikTok; Artificial intelligence; Short video; ...
#
#                                         Publisher  Source  Cited
# 0                    EMERALD GROUP PUBLISHING LTD  wos-ai      0
# 1                                        SPRINGER  wos-ai      0
# 2  IEEE-INST ELECTRICAL ELECTRONICS ENGINEERS INC  wos-ai      0
# 3                    EMERALD GROUP PUBLISHING LTD  wos-ai      0
# 4                    EMERALD GROUP PUBLISHING LTD  wos-ai      0

# %%
len(df_wos)
# Out:
# 538

# %%
# df_wos.groupby('Source').count()
# Out:
#                                  Title  Authors  Year  DOI  Abstract  \
# Source
# wos-Internet of Things               9        9     9    9         9
# wos-IoT                              4        4     4    3         4
# wos-ai                             127      127   127  126       127
# wos-artificial intelligence         69       69    69   68        69
# wos-automation                      13       13    13   13        13
# wos-autonomous                      28       28    28   27        27
# wos-big data                       150      150   150  147       150
# wos-chatbot                          5        5     5    5         5
# wos-computer vision                  1        1     1    1         1
# wos-data mining                     48       48    48   45        48
# wos-data science                    10       10    10   10        10
# wos-fuzzy logic                     19       19    19   17        19
# wos-genetic algorithm               16       16    16   14        16
# wos-k-means                         16       16    16   15        16
# wos-machine learning                47       47    47   47        47
# wos-natural language processing      2        2     2    2         2
# wos-neural network                  40       40    40   38        40
# wos-prediction                     137      137   137  132       137
# wos-recommendation                 111      111   111  108       111
# wos-robot                            2        2     2    1         2
# wos-smart technologies               1        1     1    1         1
# wos-soft computing                   2        2     2    2         2
# wos-text mining                     16       16    16   16        16
#
#                                  Keywords  Publisher  Cited
# Source
# wos-Internet of Things                  9          9      9
# wos-IoT                                 4          4      4
# wos-ai                                122        127    127
# wos-artificial intelligence            67         69     69
# wos-automation                         12         13     13
# wos-autonomous                         23         28     28
# wos-big data                          144        150    150
# wos-chatbot                             5          5      5
# wos-computer vision                     1          1      1
# wos-data mining                        47         48     48
# wos-data science                        9         10     10
# wos-fuzzy logic                        19         19     19
# wos-genetic algorithm                  16         16     16
# wos-k-means                            16         16     16
# wos-machine learning                   45         47     47
# wos-natural language processing         2          2      2
# wos-neural network                     38         40     40
# wos-prediction                        115        137    137
# wos-recommendation                     96        111    111
# wos-robot                               2          2      2
# wos-smart technologies                  1          1      1
# wos-soft computing                      2          2      2
# wos-text mining                        15         16     16

# %%
df_wos.groupby('Source').count()
# Out:
#                                  Title  Authors  Year  DOI  Abstract  \
# Source
# wos-Internet of Things               4        4     4    4         4
# wos-ai                              94       94    94   92        94
# wos-artificial intelligence         50       50    50   50        50
# wos-automation                       6        6     6    6         6
# wos-autonomous                      12       12    12   11        12
# wos-big data                        95       95    95   93        95
# wos-chatbot                          4        4     4    4         4
# wos-data mining                     37       37    37   35        37
# wos-data science                     5        5     5    5         5
# wos-fuzzy logic                     15       15    15   13        15
# wos-genetic algorithm                7        7     7    5         7
# wos-k-means                         19       19    19   18        19
# wos-machine learning                30       30    30   29        30
# wos-natural language processing      2        2     2    2         2
# wos-neural network                  16       16    16   14        16
# wos-prediction                      65       65    65   62        65
# wos-recommendation                  66       66    66   61        66
# wos-smart technologies               2        2     2    2         2
# wos-soft computing                   2        2     2    2         2
# wos-text mining                      7        7     7    7         7
#
#                                  Keywords  Publisher  Cited
# Source
# wos-Internet of Things                  4          4      4
# wos-ai                                 92         94     94
# wos-artificial intelligence            49         50     50
# wos-automation                          6          6      6
# wos-autonomous                         11         12     12
# wos-big data                           91         95     95
# wos-chatbot                             3          4      4
# wos-data mining                        35         37     37
# wos-data science                        5          5      5
# wos-fuzzy logic                        15         15     15
# wos-genetic algorithm                   7          7      7
# wos-k-means                            19         19     19
# wos-machine learning                   28         30     30
# wos-natural language processing         2          2      2
# wos-neural network                     16         16     16
# wos-prediction                         57         65     65
# wos-recommendation                     58         66     66
# wos-smart technologies                  2          2      2
# wos-soft computing                      2          2      2
# wos-text mining                         7          7      7

# %%
# df_wos.to_excel('wos_artigos.xlsx')

# %%
df_wos.sort_values('Cited', ascending=False).head(20)
# Out:
#                                                  Title  \
# 525  Consumer decision making in online shopping en...
# 459  Decision-making under uncertainty: Capturing d...
# 458  Consumption self-control by rationing purchase...
# 522  Reactance to recommendations: When unsolicited...
# 138  User generated content: the use of blogs for t...
# 447  WHAT'S ADVERTISING CONTENT WORTH? EVIDENCE FRO...
# 425  A new hybrid classification algorithm for cust...
# 524  Market situation interpretation and response: ...
# 510  The effects of blogger recommendations on cust...
# 135                      Online relationship marketing
# 295  Integrating AHP and data mining for product re...
# 86   Machine learning and AI in marketing - Connect...
# 328  Modeling the internet of things adoption barri...
# 157  Futurizing smart service: implications for ser...
# 270  Using Data Sciences in Digital Marketing: Fram...
# 520  Conceptualization and measurement of relations...
# 518          Recommendation systems with purchase data
# 375                       Consideration-set heuristics
# 127  An integrated artificial intelligence framewor...
# 373  Customer Acquisition via Display Advertising U...
#
#                                                Authors  Year  \
# 525                                Häubl, G; Trifts, V  2000
# 459                                Erdem, T; Keane, MP  1996
# 458                                     Wertenbroch, K  1998
# 522                        Fitzsimons, GJ; Lehmann, DR  2004
# 138                                        Akehurst, G  2009
# 447  Bertrand, M; Karlan, D; Mullainathan, S; Shafi...  2010
# 425           De Caigny, A; Coussement, K; De Bock, KW  2018
# 524              White, JC; Varadarajan, PR; Dacin, PA  2003
# 510                      Hsu, CL; Lin, JCC; Chiang, HS  2013
# 135   Steinhoff, L; Arli, D; Weaven, S; Kozlenkova, IV  2019
# 295                                  Liu, DR; Shih, YY  2005
# 86                                     Ma, LY; Sun, BH  2020
# 328    Kamble, SS; Gunasekaran, A; Parekh, H; Joshi, S  2019
# 157  Wünderlich, NV; Heinonen, K; Ostrom, AL; Patri...  2015
# 270                                          Saura, JR  2021
# 520                                        Huntley, JK  2006
# 518                                       Bodapati, AV  2008
# 375                                         Hauser, JR  2014
# 127           Bag, S; Gupta, S; Kumar, A; Sivarajah, U  2021
# 373               Schwartz, EM; Bradlow, ET; Fader, PS  2017
#
#                                   DOI  \
# 525         10.1287/mksc.19.1.4.15178
# 459               10.1287/mksc.15.1.1
# 458             10.1287/mksc.17.4.317
# 522            10.1287/mksc.1030.0033
# 138         10.1007/s11628-008-0054-2
# 447       10.1162/qjec.2010.125.1.263
# 425        10.1016/j.ejor.2018.02.009
# 524        10.1509/jmkg.67.3.63.18654
# 510         10.1108/10662241311295782
# 135         10.1007/s11747-018-0621-6
# 295          10.1016/j.im.2004.01.008
# 86     10.1016/j.ijresmar.2020.04.005
# 328  10.1016/j.jretconser.2019.02.020
# 157          10.1108/JSM-01-2015-0040
# 270         10.1016/j.jik.2020.08.001
# 520   10.1016/j.indmarman.2005.05.011
# 518              10.1509/jmkr.45.1.77
# 375     10.1016/j.jbusres.2014.02.015
# 127   10.1016/j.indmarman.2020.12.001
# 373            10.1287/mksc.2016.1023
#
#                                               Abstract  \
# 525  Despite the explosive growth of electronic com...
# 459  We construct two models of the behavior of con...
# 458  Consumers' attempts to control their unwanted ...
# 522  Recommendations often play a positive role in ...
# 138  As the World Wide Web has developed considerab...
# 447  Firms spend billions of dollars developing adv...
# 425  Decision trees and logistic regression are two...
# 524  Improving marketing decision making requires a...
# 510  Purpose - Blogging has become part of a consum...
# 135  Online interactions have emerged as a dominant...
# 295  Product recommendation is a business activity ...
# 86   Artificial intelligence (AI) agents driven by ...
# 328  Internet of things (IoT) is estimated to play ...
# 157  Purpose - The purpose of this paper is to craf...
# 270  In the last decade, the use of Data Sciences, ...
# 520  Following over a decade of relationship market...
# 518  Many firms use decision tools called automatic...
# 375  Consumers often choose products by first formi...
# 127  This study examines the effect of big data pow...
# 373  Firms using online advertising regularly run e...
#
#                                               Keywords  \
# 525                                                NaN
# 459                                                NaN
# 458  intertemporal choice; pricing policy; product ...
# 522  recommendations; intelligent agents; decision ...
# 138  User generated content; Blogs; Tourism; Travel...
# 447                                                NaN
# 425  OR in marketing; Hybrid algorithm; Customer ch...
# 524                                                NaN
# 510  Blogging; Recommendations; Online shopping; Tr...
# 135  Relationship marketing; Relationship selling; ...
# 295  recommendation; marketing analytic hierarchy p...
# 86   Artificial intelligence (AI); Machine learning...
# 328  Internet of things; Retail supply chain; ISM; ...
# 157  Connected services; Intelligent object; New se...
# 270  Data Sciences; Digital Marketing; Knowledge di...
# 520  relationship quality; relationship marketing; ...
# 518  customer relationship management; one-to-one m...
# 375  Consideration sets; Decision heuristics; Fast-...
# 127  Artificial intelligence; Big data; Knowledge m...
# 373  multi-armed bandit; online advertising; field ...
#
#                                         Publisher  \
# 525  INST OPERATIONS RESEARCH MANAGEMENT SCIENCES
# 459  INST OPERATIONS RESEARCH MANAGEMENT SCIENCES
# 458  INST OPERATIONS RESEARCH MANAGEMENT SCIENCES
# 522                                       INFORMS
# 138                           SPRINGER HEIDELBERG
# 447                         OXFORD UNIV PRESS INC
# 425                                      ELSEVIER
# 524                         SAGE PUBLICATIONS INC
# 510                  EMERALD GROUP PUBLISHING LTD
# 135                                      SPRINGER
# 295                                      ELSEVIER
# 86                                       ELSEVIER
# 328                              ELSEVIER SCI LTD
# 157                  EMERALD GROUP PUBLISHING LTD
# 270                               ELSEVIER ESPANA
# 520                          ELSEVIER SCIENCE INC
# 518                         SAGE PUBLICATIONS INC
# 375                          ELSEVIER SCIENCE INC
# 127                          ELSEVIER SCIENCE INC
# 373                                       INFORMS
#
#                           Source  Cited
# 525           wos-recommendation   1015
# 459               wos-prediction    681
# 458               wos-prediction    610
# 522           wos-recommendation    431
# 138  wos-artificial intelligence    312
# 447               wos-prediction    303
# 425               wos-prediction    283
# 524           wos-recommendation    263
# 510           wos-recommendation    249
# 135  wos-artificial intelligence    246
# 295              wos-data mining    232
# 86                        wos-ai    226
# 328       wos-Internet of Things    212
# 157               wos-autonomous    197
# 270              wos-data mining    191
# 520           wos-recommendation    175
# 518           wos-recommendation    175
# 375         wos-machine learning    175
# 127  wos-artificial intelligence    169
# 373         wos-machine learning    163

# %%
print(f'Number of articles in Web of Science Data Base: {len(df_wos)}')
# Out:
# Number of articles in Web of Science Data Base: 538

# %% [markdown]
# ### Create DataFrame Pandas with Scopus records

# %%
# Directory containing the .xls files
directory = 'data/articles/scopus'

dataframes = []

# Iterate over all files in the specified folder
for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        file_path = os.path.join(directory, filename)
        df = pd.read_csv(file_path)    
        df['Source'] = directory.split('/')[-1]+'-'+filename.split('.')[0]    
        dataframes.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# If duplicates based on the "Article Title" field, to remove!
df_scopus = combined_df.drop_duplicates(subset=['Title'])
df_scopus.reset_index(drop=True, inplace=True)

df_scopus = df_scopus[['Title','Authors','Year','DOI','Abstract','Author Keywords','Publisher','Source','Cited by']]
df_scopus.columns = ['Title','Authors','Year','DOI','Abstract','Keywords','Publisher','Source','Cited']

df_scopus.head()
# Out:
#                                                Title  \
# 0  IMPACT OF HORTICULTURE ON THE SUSTAINABLE LIVE...
# 1  Out of the fog: fog computing-enabled AI to su...
# 2  The Role of AI in Enhancing Marketing Communic...
# 3  Deploying artificial intelligence in services ...
# 4  THE IMPACT OF BRAND-VOICE INTEGRATION AND ARTI...
#
#                                              Authors  Year  \
# 0  Mukherjee D.; Jena L.K.; Chakraborty S.; Debna...  2024
# 1                    Hornik J.; Ofir C.; Rachamim M.  2024
# 2                          Isnaini S.; Muslimin A.I.  2024
# 3              Hermann E.; Williams G.Y.; Puntoni S.  2024
# 4                 Murár P.; Kubovics M.; Jurišová V.  2024
#
#                                               DOI  \
# 0                      10.51599/ARE.2024.10.02.04
# 1                      10.1007/s11301-024-00441-0
# 2                         10.11114/smc.v12i4.7013
# 3                      10.1007/s11747-023-00986-8
# 4  10.34135/COMMUNICATIONTODAY.2024.VOL.15.NO.1.4
#
#                                             Abstract  \
# 0  Purpose. The perishable nature of the horticul...
# 1  Marketing and consumer research use a variety ...
# 2  This research delves into the transformative i...
# 3  Despite offering substantial opportunities to ...
# 4  Corporate identity plays an important role in ...
#
#                                             Keywords  \
# 0  economics; horticulture; livelihood developmen...
# 1  Artificial intelligence (AI); Digital marketin...
# 2  artificial intelligence; development; higher e...
# 3  Artificial intelligence; Ethics; Justice; Serv...
# 4  artificial intelligence; brand communication; ...
#
#                                            Publisher     Source  Cited
# 0  Institute of Eastern European Research and Con...  scopus-ai      0
# 1                                    Springer Nature  scopus-ai      1
# 2                            Redfame Publishing Inc.  scopus-ai      0
# 3                                           Springer  scopus-ai     11
# 4  University of SS. Cyril and Methodius, Faculty...  scopus-ai      3

# %%
print(f'Number of articles in Scopus Data Base: {len(df_scopus)}')
# Out:
# Number of articles in Scopus Data Base: 1754

# %% [markdown]
# ### Group WOS and Scorpus

# %%
df_all = pd.concat([df_scopus,df_wos])
df_all.head()
# Out:
#                                                Title  \
# 0  IMPACT OF HORTICULTURE ON THE SUSTAINABLE LIVE...
# 1  Out of the fog: fog computing-enabled AI to su...
# 2  The Role of AI in Enhancing Marketing Communic...
# 3  Deploying artificial intelligence in services ...
# 4  THE IMPACT OF BRAND-VOICE INTEGRATION AND ARTI...
#
#                                              Authors  Year  \
# 0  Mukherjee D.; Jena L.K.; Chakraborty S.; Debna...  2024
# 1                    Hornik J.; Ofir C.; Rachamim M.  2024
# 2                          Isnaini S.; Muslimin A.I.  2024
# 3              Hermann E.; Williams G.Y.; Puntoni S.  2024
# 4                 Murár P.; Kubovics M.; Jurišová V.  2024
#
#                                               DOI  \
# 0                      10.51599/ARE.2024.10.02.04
# 1                      10.1007/s11301-024-00441-0
# 2                         10.11114/smc.v12i4.7013
# 3                      10.1007/s11747-023-00986-8
# 4  10.34135/COMMUNICATIONTODAY.2024.VOL.15.NO.1.4
#
#                                             Abstract  \
# 0  Purpose. The perishable nature of the horticul...
# 1  Marketing and consumer research use a variety ...
# 2  This research delves into the transformative i...
# 3  Despite offering substantial opportunities to ...
# 4  Corporate identity plays an important role in ...
#
#                                             Keywords  \
# 0  economics; horticulture; livelihood developmen...
# 1  Artificial intelligence (AI); Digital marketin...
# 2  artificial intelligence; development; higher e...
# 3  Artificial intelligence; Ethics; Justice; Serv...
# 4  artificial intelligence; brand communication; ...
#
#                                            Publisher     Source  Cited
# 0  Institute of Eastern European Research and Con...  scopus-ai      0
# 1                                    Springer Nature  scopus-ai      1
# 2                            Redfame Publishing Inc.  scopus-ai      0
# 3                                           Springer  scopus-ai     11
# 4  University of SS. Cyril and Methodius, Faculty...  scopus-ai      3

# %%
print(f'Number of articles in Scopus and Web of Science Data Base: {len(df_all)}')
# Out:
# Number of articles in Scopus and Web of Science Data Base: 2292

# %%
# Remove duplicate
df_all = df_all.drop_duplicates(subset=['Title'])

# Remove empty
df_all = df_all[~df_all['Abstract'].isna()]

df_all.reset_index(inplace=True, drop=True)

print(f'Number of articles less duplicates and empty abstract: {len(df_all)}')
# Out:
# Number of articles less duplicates and empty abstract: 2043

# %% [markdown]
# ### Save all data in .csv

# %%
df_all.to_csv('data/articles/all_articles.csv', index=False)
